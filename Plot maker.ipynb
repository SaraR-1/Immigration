# %%
import json
import numpy as np
import pickle
import plot_function
import map_visualization
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.lines as mlines
import sys

# %%
palette_region = json.load(open('Statistics/color_region_dict.json'))
palette_zone = json.load(open('Statistics/color_zone_dict.json'))
palette_continent = json.load(open('Statistics/color_continent_dict.json'))
palette_country = json.load(open('Statistics/color_country_dict.json'))
palette_country = {i: [float(c) for c in j] for i, j in palette_country.items()}
with open ('Statistics/countries_list.txt', 'rb') as fp:
    countries_list = pickle.load(fp)
Africa_palette = json.load(open('Statistics/Africa_palette.json'))
Asia_palette = json.load(open('Statistics/Asia_palette.json'))
Europe_palette = json.load(open('Statistics/Europe_palette.json'))
Pacific_palette = json.load(open('Statistics/Pacific_palette.json'))
America_palette = json.load(open('Statistics/America_palette.json'))    
years = list(range(2003, 2018))

# %% [markdown]
# ### Region Plots

# %%
plot_function.line_per_year('Statistics/region_abs.json', years, "Region", "Abs Population", "Region distribution", palette_region, save = True, path = "Plots/region_abs")

# %%
plot_function.line_per_year('Statistics/region_abs_growth.json', years, "Region", "Abs Growth Population", "Region distribution", palette_region, save = True, path = "Plots/region_abs_growth", key = False)

# %%
plot_function.line_per_year('Statistics/region_prev_growth.json', years, "Region", "Growth Rate Population", "Region distribution", palette_region, save = True, path = "Plots/region_prev_growth", key = False)

# %% [markdown]
# ### Zone Plots

# %%
plot_function.line_per_year('Statistics/zone_abs.json', years, "zone", "Abs Population", "Zone distribution", palette_zone, save = True, path = "Plots/zone")

# %%
plot_function.line_per_year('Statistics/zone_abs_growth.json', years, "zone", "Abs Growth Population", "Zone distribution", palette_zone, save = True, path = "Plots/zone_abs_growth", key = False)

# %%
plot_function.line_per_year('Statistics/zone_prev_growth.json', years, "zone", "Growth Rate Population", "Zone distribution", palette_zone, save = True, path = "Plots/zone_prev_growth", key = False)

# %% [markdown]
# ### Male vs Female

# %%
plot_function.stacked_barplot('Statistics/gender_distribution.json', years, "Years", "Abs Frequency", "Male VS Female Immigration Frequencies", save = True, path = "Plots/gender_distribution")

# %% [markdown]
# ### Map Visualization  - Region Distribution

# %%
map_visualization.map_vis('Statistics/region_abs.json', 2017)

# %% [markdown]
# ### Zone - continent Plot

# %%
plot_function.multiple_line_per_year('Statistics/py_zone_continent.json', years, "Abs Population", "Continent distribution in ", palette_continent, save = True, path = "Plots/continent_distr_")

# %% [markdown]
# ### Zone - top 10 countries per continent Plot

# %%
plot_function.multiple_line_per_year('Statistics/py_zone_top10_countrie_cont.json', years, "Abs Population", "Top 10 countries per continent distribution in ", palette_country, countries_list, save = True, path = "Plots/zone_top10_countrie_cont_")

# %% [markdown]
# ### Zone - top 5 countries per continent Plot

# %%
plot_function.multiple_line_per_year('Statistics/py_zone_top5_countrie_cont.json', years, "Abs Population", "Top 5 countries per continent distribution in ", palette_country, countries_list, save = True, path = "Plots/zone_top5_countrie_cont_")

# %% [markdown]
# ### Zone - Countries distribution for each continent

# %%
plot_function.multiple_line_per_year('Statistics/py_zone_Africa_countries.json', years, "Abs Population", "Africa countries distribution in ", Africa_palette, countries_list, save = True, path = "Plots/py_zone_Africa_countries_")
plot_function.multiple_line_per_year('Statistics/py_zone_Asia_countries.json', years, "Abs Population", "Asia countries distribution in ", Asia_palette, countries_list, save = True, path = "Plots/py_zone_Asia_countries_")
plot_function.multiple_line_per_year('Statistics/py_zone_Europe_countries.json', years, "Abs Population", "Europe countries distribution in ", Europe_palette, countries_list, save = True, path = "Plots/py_zone_Europe_countries_")
plot_function.multiple_line_per_year('Statistics/py_zone_America_countries.json', years, "Abs Population", "America countries distribution in ", America_palette, countries_list, save = True, path = "Plots/py_zone_America_countries_")
plot_function.multiple_line_per_year('Statistics/py_zone_Pacific_countries.json', years, "Abs Population", "Pacific countries distribution in ", Pacific_palette, countries_list, save = True, path = "Plots/py_zone_Pacific_countries_")

# %% [markdown]
# ### Region - continent Plot

# %%
plot_function.multiple_line_per_year('Statistics/py_region_continent.json', years, "Abs Population", "Continent distribution in ", palette_continent, save = True, path = "Plots/continent_distr_")

# %% [markdown]
# ### Region - top 10 countries per continent Plot

# %%
plot_function.multiple_line_per_year('Statistics/py_region_top10_countrie_cont.json', years, "Abs Population", "Top 10 countries per continent distribution in ", palette_country, countries_list, save = True, path = "Plots/region_top10_countrie_cont_")

# %% [markdown]
# ### Region - top 5 countries per continent Plot

# %%
plot_function.multiple_line_per_year('Statistics/py_region_top5_countrie_cont.json', years, "Abs Population", "Top 5 countries per continent distribution in ", palette_country, countries_list, save = True, path = "Plots/region_top5_countrie_cont_")

# %% [markdown]
# ### Region - Countries distribution for each continent

# %%
plot_function.multiple_line_per_year('Statistics/py_region_Africa_countries.json', years, "Abs Population", "Africa countries distribution in ", Africa_palette, countries_list, save = True, path = "Plots/py_region_Africa_countries_")
plot_function.multiple_line_per_year('Statistics/py_region_Asia_countries.json', years, "Abs Population", "Asia countries distribution in ", Asia_palette, countries_list, save = True, path = "Plots/py_region_Asia_countries_")
plot_function.multiple_line_per_year('Statistics/py_region_Europe_countries.json', years, "Abs Population", "Europe countries distribution in ", Europe_palette, countries_list, save = True, path = "Plots/py_region_Europe_countries_")
plot_function.multiple_line_per_year('Statistics/py_region_America_countries.json', years, "Abs Population", "America countries distribution in ", America_palette, countries_list, save = True, path = "Plots/py_region_America_countries_")
plot_function.multiple_line_per_year('Statistics/py_region_Pacific_countries.json', years, "Abs Population", "Pacific countries distribution in ", Pacific_palette, countries_list, save = True, path = "Plots/py_region_Pacific_countries_")

# %%
plot_function.multiple_line_per_year('Statistics/py_zone_country.json', years, "Abs Population", "Countries distribution in ", palette_country, countries_list, save = False)
